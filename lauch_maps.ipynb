# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import *

# %%
longs_tot, lats_tot = compute_and_plot_track(['hubert', 'pa'], step=2, round=5, with_map=True, dpi=1000)

# %%
longs_tot, lats_tot = plot_track(['pa'], step=2, round=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 longs_tot, lats_tot = plot_track(['pa'], step=2, round=5)
#
# TypeError: plot_track() missing 3 required positional arguments: 'gpx_infos', 'colors', and 'lws'

# %%
xs_tot, ys_tot = plot_track_density_mask(['hubert'], step=1, radius_meters=50, time_excl_window=100)
